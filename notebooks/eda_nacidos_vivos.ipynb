# %% [markdown]
# <a href="https://colab.research.google.com/github/cgonzalez022407-art/nacidos-vivos-eda/blob/main/notebooks/eda_nacidos_vivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

base = "https://raw.githubusercontent.com/cgonzalez022407-art/nacidos-vivos-eda/main/data/"

df21 = pd.read_csv(base + "nacweb21_0.csv", sep=';', low_memory=False)
df22 = pd.read_csv(base + "nacweb22_0.csv", sep=';', low_memory=False)
df23 = pd.read_csv(base + "nacweb23.csv",   sep=';', low_memory=False)

for y, df in [("2021", df21), ("2022", df22), ("2023", df23)]:
    print(f"\nAño {y} -> shape:", df.shape)
    display(df.head(3))
# Out:
# Año 2021 -> shape: (10072, 8)
#    PROVRES  TIPPARTO  SEXO     IMEDAD          ITIEMGEST  \
# 0       99         1     1  4.25 a 29  8.Sin especificar
# 1       82         1     2  5.30 a 34          4.28 a 31
# 2        6         1     1  2.15 a 19          3.24 a 27
#
#                            IMINSTRUC                IPESONAC  CUENTA
# 0    1.Hasta Primaria/C.EGB Completa     2.2500 gramos y más       1
# 1  2.Secundaria/Polimodal Incompleta  1.Menos de 2500 gramos       5
# 2                  4.Sin especificar  1.Menos de 2500 gramos       1
# Año 2022 -> shape: (9693, 8)
#    PROVRES  TIPPARTO  SEXO     IMEDAD   ITIEMGEST  \
# 0       90         1     1  4.25 a 29   3.24 a 27
# 1       66         1     2  6.35 a 39  7.42 y más
# 2       50         1     1  4.25 a 29   3.24 a 27
#
#                                IMINSTRUC                IPESONAC  CUENTA
# 0  3.Secundario/Polimodal Completa y más       3.Sin especificar       1
# ...
